# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedDanishAhmed84/flyrank/blob/main/w06_validation_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %%
### Finding 1

**Finding:** [Copy/paraphrase the actual finding from the paper.]

**My methodology question:** How was the label/outcome for this finding defined, and was it based on an observed outcome or a constructed proxy? I would want to understand this because the interpretation depends on how the outcome was defined.

### Finding 2

**Finding:** [Copy/paraphrase the actual finding from the paper.]

**My methodology question:** Does the validation design support the strength of the claim? In particular, I would want to know whether the evaluation split prevents information from related observations or future periods from influencing the evaluation.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %%
Original split → metric
Honest time/group split → metric

# %% [markdown]
# ## 2. My model under an honest split
#
# I first evaluated the Week-5 model using the original validation approach. I then re-ran the model using a time-aware split, training on earlier observations and evaluating on later observations.
#
# | Evaluation | Metric |
# |---|---:|
# | Original split | [YOUR ACTUAL NUMBER] |
# | Time-aware split | [YOUR ACTUAL NUMBER] |
#
# The change in performance shows how the evaluation result depends on the validation design. The time-aware result is the more relevant estimate for a future-facing decision because it better reflects the direction of time in the data.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %%
I audited the final feature set based on whether each feature would have been available at the decision moment. Features derived from future outcomes or directly from the target would create leakage and were excluded.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %%
The model provides directional decision support for prioritizing pages for human review based on observed historical content and search-performance signals.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
